# %%
import pandas as pd

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('essays.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Text'], df['Topic'], test_size=0.2, random_state=42)

model = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', MultinomialNB())
])
model.fit(X_train, y_train)
y_pred =model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(accuracy*100)
# Out:
# 100.0

# %%
import joblib
joblib.dump(model,'model.pkl')
# Out:
# ['model.pkl']

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df
# Out:
#                                                     Text      Topic
# 0      What are the symptoms of COVID-19 What should ...     Health
# 1                     How to prepare for a job interview     Career
# 2      How do I invest in the stock market What shoul...    Finance
# 3      How do I invest in the stock market What shoul...    Finance
# 4      How to prepare for a job interview What should...     Career
# ...                                                  ...        ...
# 11995  The government announced a new education polic...  Education
# 11996  What are the symptoms of COVID-19 What's impor...     Health
# 11997  How to prepare for a job interview What should...     Career
# 11998  Renewable energy is the future. What's important?     Energy
# 11999       How to bake a chocolate cake Please explain.    Cooking
#
# [12000 rows x 2 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
def check_plagiarism(user_input, dataset_texts, threshold=0.2):

    all_texts = dataset_texts.tolist() + [user_input]

    vectorizer = TfidfVectorizer().fit(all_texts)
    tfidf_matrix = vectorizer.transform(all_texts)

    cosine_similarities = cosine_similarity(tfidf_matrix[-1], tfidf_matrix[:-1]).flatten()
    print( cosine_similarities)
    max_sim = np.max(cosine_similarities)
    max_index = np.argmax(cosine_similarities)

    print(f"Max similarity with dataset text: {max_sim:.2f} (Text: \"{dataset_texts.iloc[max_index]}\")")

    if max_sim >= threshold:
        print(f"Plagiarized! Similarity: {max_sim*100:.1f}%")
    else:
        print(f"Not plagiarized. Highest similarity: {max_sim*100:.1f}%")

user_text = "my name is rameez"

check_plagiarism(user_text, df['Text'])
# Out:
# [0.       0.       0.       ... 0.       0.039669 0.      ]
# Max similarity with dataset text: 0.05 (Text: "What is the capital of France")
# Not plagiarized. Highest similarity: 4.8%

# %%
import joblib
